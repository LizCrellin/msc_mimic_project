# %%
import numpy as np
import pandas as pd
from pathlib import Path
import getpass
from sqlalchemy import create_engine, text
import os
from dotenv import load_dotenv
from matplotlib import pyplot

# %%
PROJECT_ROOT = Path.cwd().parents[0]   # adjust after checking Path.cwd()
TABLES_DIR = PROJECT_ROOT / 'results' / 'tables'
load_dotenv()
BACKUP_ROOT = Path(os.environ["BACKUP_ROOT"])
DATA_DIR = BACKUP_ROOT / 'results' / 'data'
REPRESENTATIVE_VARS = ['heart_rate', 'sbp', 'dbp', 'resp_rate', 'spo2', 'glucose_vital', 'gcs', 'creatinine', 'potassium', 'wbc']

# %%
pg_user = 'postgres'      # same value you use to connect via psql
pg_host = 'localhost'          # or wherever your Postgres server is
pg_port = 5432
pg_dbname = 'mimiciv'

pg_password = getpass.getpass('Postgres password: ')

engine = create_engine(
    f'postgresql+psycopg2://{pg_user}:{pg_password}@{pg_host}:{pg_port}/{pg_dbname}'
)

# %%
# Restrict to Train dataset
Ys_train = pd.read_parquet(DATA_DIR / 'Ys_train.parquet', engine='pyarrow')
train_ids = sorted(set(Ys_train.index.get_level_values('icustay_id')))
n_train = len(train_ids)
print(n_train)
# Out:
# 36286

# %%
# Read in the hourly aggregated dataset

hourly_ds = pd.read_sql(text("SELECT * FROM msc_project.hourly_data WHERE icustay_id = ANY(:ids)"), engine, params = {'ids': train_ids})

hourly_id_cols = ['subject_id', 'hadm_id', 'icustay_id', 'hours_in', 'hour_end']
hourly_vars = [c for c in hourly_ds.columns if c not in hourly_id_cols]

# %%
# Read in the summary representation dataset

summary_ds = pd.read_sql(text("SELECT * FROM msc_project.alternative_data WHERE icustay_id = ANY(:ids)"), engine, params = {'ids': train_ids})

summary_ds.head()
# Out:
#    subject_id   hadm_id  icustay_id variable_name  value_min  value_max  \
# 0    12466550  23998182    30000153      aniongap       12.0       12.0
# 1    12466550  23998182    30000153   bicarbonate       19.0       23.0
# 2    12466550  23998182    30000153           bun       22.0       22.0
# 3    12466550  23998182    30000153       calcium        7.4        8.0
# 4    12466550  23998182    30000153      chloride      115.0      115.0
#
#    value_avg  value_std  value_count  value_first  value_last  \
# 0       12.0   0.000000            2         12.0        12.0
# 1       21.0   2.828427            2         19.0        23.0
# 2       22.0   0.000000            2         22.0        22.0
# 3        7.7   0.424264            2          7.4         8.0
# 4      115.0   0.000000            2        115.0       115.0
#
#    value_first_time  value_last_time  value_slope
# 0          3.466667        15.416667     0.000000
# 1          3.466667        15.416667     0.334728
# 2          3.466667        15.416667     0.000000
# 3          3.466667        15.416667     0.050209
# 4          3.466667        15.416667     0.000000

# %%
# Pivot summary representation dataset to wide

summary_flat_mean = summary_ds.pivot_table(index='icustay_id', columns='variable_name', values= 'value_avg')

summary_flat_mean.head()
# Out:
# variable_name  albumin  aniongap  bicarbonate        bun   calcium  \
# icustay_id
# 30000153           NaN     12.00    21.000000  22.000000  7.700000
# 30000646           NaN     12.25    24.000000  11.000000  7.650000
# 30000831           NaN     16.00    25.000000  70.000000  9.066667
# 30001336           3.3     16.00    23.666667  17.666667  8.533333
# 30001396           NaN     13.00    30.000000  19.500000  8.750000
#
# variable_name    chloride  creatinine    dbp      gcs  globulin  ...  \
# icustay_id                                                       ...
# 30000153       115.000000    1.000000  66.28  13.1875       NaN  ...
# 30000646       107.500000    0.875000    NaN  15.0000       NaN  ...
# 30000831       103.333333    2.200000    NaN  13.0000       NaN  ...
# 30001336        97.000000    1.033333    NaN  15.0000       NaN  ...
# 30001396       102.000000    1.350000    NaN  14.5000       NaN  ...
#
# variable_name  potassium    rbc    rdw  resp_rate     sbp      sodium  \
# icustay_id
# 30000153            4.60  3.185  13.40  15.000000  135.72  143.500000
# 30000646            3.85  4.375  15.25  25.666667     NaN  139.750000
# 30000831            3.80  4.400  12.20  26.804348     NaN  144.333333
# 30001336            3.90  2.870  12.00  26.185185     NaN  132.666667
# 30001396            3.95  4.350  14.25  22.708333     NaN  141.000000
#
# variable_name       spo2  temperature  total_protein     wbc
# icustay_id
# 30000153       96.769231    37.312500            NaN  16.100
# 30000646       95.650000    37.334444            NaN   8.825
# 30000831       94.521739    37.543333            NaN  17.750
# 30001336       96.444444    36.855714            NaN   8.550
# 30001396       90.333333    37.427143            NaN  12.100
#
# [5 rows x 30 columns]

# %%
# data types - hourly
types_hourly = hourly_ds.dtypes
print(types_hourly)
# all float64
# Out:
# subject_id                int64
# hadm_id                   int64
# icustay_id                int64
# hours_in                  int64
# hour_end         datetime64[us]
# heart_rate              float64
# sbp                     float64
# dbp                     float64
# mbp                     float64
# resp_rate               float64
# temperature             float64
# spo2                    float64
# glucose_vital           float64
# albumin                 float64
# globulin                float64
# total_protein           float64
# aniongap                float64
# bicarbonate             float64
# bun                     float64
# calcium                 float64
# chloride                float64
# creatinine              float64
# sodium                  float64
# potassium               float64
# magnesium               float64
# gcs                     float64
# hematocrit              float64
# hemoglobin              float64
# mch                     float64
# mchc                    float64
# mcv                     float64
# platelet                float64
# rbc                     float64
# rdw                     float64
# wbc                     float64
# dtype: object

# %%
# data types - summary
types_summary = summary_flat_mean.dtypes
print(types_summary)
# Out:
# variable_name
# albumin          float64
# aniongap         float64
# bicarbonate      float64
# bun              float64
# calcium          float64
# chloride         float64
# creatinine       float64
# dbp              float64
# gcs              float64
# globulin         float64
# glucose_vital    float64
# heart_rate       float64
# hematocrit       float64
# hemoglobin       float64
# magnesium        float64
# mbp              float64
# mch              float64
# mchc             float64
# mcv              float64
# platelet         float64
# potassium        float64
# rbc              float64
# rdw              float64
# resp_rate        float64
# sbp              float64
# sodium           float64
# spo2             float64
# temperature      float64
# total_protein    float64
# wbc              float64
# dtype: object

# %%
#  statistics - hourly

description_hourly = hourly_ds[hourly_vars].describe()
print(description_hourly)
# Out:
#           heart_rate            sbp            dbp            mbp  \
# count  829373.000000  313620.000000  313562.000000  315404.000000
# mean       84.349974     116.310797      58.501207      77.675702
# std        18.195185      19.386800      11.711822      14.497597
# min        12.000000       4.000000       1.000000       1.000000
# 25%        71.000000     103.000000      51.000000      69.000000
# 50%        83.000000     114.000000      57.000000      76.000000
# 75%        95.500000     127.500000      65.000000      84.500000
# max       280.000000     357.000000     293.000000     299.000000
#
#            resp_rate    temperature           spo2  glucose_vital  \
# count  821209.000000  280169.000000  803032.000000  242964.000000
# mean       19.213143      36.900336      96.810965     236.415194
# std         5.352315       0.700857       2.881036    9264.540637
# min         1.000000      22.000000       4.000000       0.120000
# 25%        15.750000      36.560000      95.000000     109.000000
# 50%        18.500000      36.890000      97.000000     131.000000
# 75%        22.000000      37.220000      99.000000     164.000000
# max        68.000000      42.300000     100.000000  999999.000000
#
#             albumin    globulin  ...            gcs     hematocrit  \
# count  17586.000000  555.000000  ...  291442.000000  109275.000000
# mean       3.221452    2.643694  ...      14.409243      31.621773
# std        0.709946    0.749709  ...       1.606627       6.330813
# min        0.500000    0.900000  ...       3.000000       7.300000
# 25%        2.700000    2.200000  ...      15.000000      27.000000
# 50%        3.200000    2.500000  ...      15.000000      31.200000
# 75%        3.700000    3.000000  ...      15.000000      35.800000
# max        5.800000    9.200000  ...      15.000000      71.200000
#
#          hemoglobin           mch          mchc           mcv      platelet  \
# count  96145.000000  94657.000000  94683.000000  94688.000000  96842.000000
# mean      10.537016     30.145379     33.115936     91.101787    190.966021
# std        2.196299      2.585604      1.629032      6.910272    104.792829
# min        2.100000     15.400000     23.500000     53.000000      5.000000
# 25%        8.900000     28.900000     32.100000     87.000000    124.000000
# 50%       10.400000     30.300000     33.200000     91.000000    174.000000
# 75%       12.000000     31.600000     34.200000     95.000000    238.000000
# max       24.600000     58.300000     70.400000    144.000000   2947.000000
#
#                 rbc           rdw           wbc
# count  94689.000000  94609.000000  94794.000000
# mean       3.517893     14.954270     12.582057
# std        0.757006      2.351763      9.829812
# min        0.740000     10.600000      0.100000
# 25%        2.970000     13.300000      7.900000
# 50%        3.480000     14.400000     11.000000
# 75%        4.020000     15.900000     15.200000
# max        8.170000     34.500000    462.600000
#
# [8 rows x 30 columns]

# %%
# summary statistics - summary ds
description_summary = summary_flat_mean.describe()
print(description_summary)
# Out:
# variable_name       albumin      aniongap   bicarbonate           bun  \
# count          13026.000000  35850.000000  35885.000000  35893.000000
# mean               3.279094     13.847976     23.076037     24.267048
# std                0.698637      3.582490      3.986211     20.087562
# min                0.600000      2.000000      4.000000      1.000000
# 25%                2.800000     11.500000     21.000000     12.500000
# 50%                3.300000     13.500000     23.000000     17.750000
# 75%                3.800000     15.666667     25.000000     28.000000
# max                5.500000     45.750000     49.000000    228.000000
#
# variable_name       calcium      chloride    creatinine           dbp  \
# count          33137.000000  35896.000000  35893.000000  16644.000000
# mean               8.406787    104.144738      1.331723     59.279124
# std                0.737247      5.800176      1.419952      9.401591
# min                4.225000     67.500000      0.100000     11.000000
# 25%                7.940000    101.000000      0.700000     53.064565
# 50%                8.400000    104.600000      0.920000     58.463850
# 75%                8.866667    107.666667      1.300000     64.463889
# max               18.100000    152.250000     32.266667    130.000000
#
# variable_name           gcs    globulin  ...     potassium           rbc  \
# count          36225.000000  530.000000  ...  35871.000000  35771.000000
# mean              14.486026    2.642862  ...      4.189147      3.642517
# std                1.138732    0.744097  ...      0.548284      0.705314
# min                3.000000    0.900000  ...      2.250000      1.173333
# 25%               14.523810    2.200000  ...      3.825000      3.140000
# 50%               15.000000    2.525000  ...      4.133333      3.607500
# 75%               15.000000    2.987500  ...      4.500000      4.112500
# max               15.000000    9.200000  ...      9.950000      7.610000
#
# variable_name           rdw     resp_rate           sbp        sodium  \
# count          35757.000000  36179.000000  16641.000000  35890.000000
# mean              14.743380     19.105002    116.807853    138.345708
# std                2.216875      3.766285     15.185828      4.656800
# min               10.750000      9.057692     16.000000    105.666667
# 25%               13.233333     16.477008    106.961538    136.000000
# 50%               14.200000     18.472222    114.453125    138.500000
# 75%               15.600000     21.076923    124.360000    141.000000
# max               34.033333     40.880000    332.000000    179.000000
#
# variable_name          spo2   temperature  total_protein           wbc
# count          36227.000000  35155.000000     943.000000  35771.000000
# mean              96.911272     36.851138       6.044256     12.155898
# std                2.000479      0.498536       1.103843      8.372113
# min               54.095238     30.985556       2.300000      0.100000
# 25%               95.720000     36.610000       5.400000      8.100000
# 50%               97.100000     36.824762       6.100000     10.950000
# 75%               98.384615     37.085857       6.700000     14.500000
# max              100.000000     39.950000      16.400000    386.700000
#
# [8 rows x 30 columns]

# %%
# Correlation coefficients - hourly

corrs_hourly = hourly_ds[hourly_vars].corr(method='pearson')
print(corrs_hourly)
# Out:
#                heart_rate       sbp       dbp       mbp  resp_rate  \
# heart_rate       1.000000 -0.078634  0.186194  0.064720   0.290533
# sbp             -0.078634  1.000000  0.443017  0.718699  -0.020065
# dbp              0.186194  0.443017  1.000000  0.850687   0.042081
# mbp              0.064720  0.718699  0.850687  1.000000   0.011492
# resp_rate        0.290533 -0.020065  0.042081  0.011492   1.000000
# temperature      0.242261 -0.002332 -0.029555 -0.048057   0.142924
# spo2            -0.110099  0.045371  0.043339  0.053557  -0.163473
# glucose_vital    0.007117 -0.001137 -0.002737 -0.000736   0.000130
# albumin         -0.179344  0.212399  0.144887  0.188935  -0.108618
# globulin        -0.030702  0.239587 -0.033078  0.205904   0.047061
# total_protein   -0.116472  0.248870  0.176338  0.332828  -0.033634
# aniongap         0.177429 -0.030525  0.027919  0.015009   0.208509
# bicarbonate     -0.126922  0.113515  0.011979  0.041021  -0.129834
# bun              0.018049 -0.037525 -0.117681 -0.081902   0.102936
# calcium         -0.108984  0.132390  0.046024  0.079631  -0.052374
# chloride        -0.035697 -0.009824  0.036762  0.013990  -0.060753
# creatinine       0.020480 -0.034106 -0.064206 -0.052776   0.067720
# sodium          -0.002598  0.071571  0.091715  0.084966   0.017864
# potassium        0.006715 -0.127748 -0.061261 -0.100443   0.019730
# magnesium       -0.072068 -0.091167 -0.098163 -0.107429  -0.010122
# gcs             -0.024949 -0.041870 -0.018841 -0.034018  -0.036842
# hematocrit      -0.034701  0.067423  0.262032  0.178944   0.047385
# hemoglobin      -0.046286  0.086181  0.278989  0.191691   0.019545
# mch             -0.030079 -0.014282 -0.015774 -0.014309  -0.054462
# mchc            -0.033921  0.041206  0.075757  0.050553  -0.106787
# mcv             -0.010737 -0.044431 -0.069282 -0.050701   0.008215
# platelet         0.036962  0.066930  0.073244  0.073840   0.058180
# rbc             -0.029644  0.087168  0.274325  0.188787   0.043400
# rdw              0.117097 -0.024040 -0.091062 -0.051365   0.096782
# wbc              0.091658 -0.074924 -0.012682 -0.038310   0.082985
#
#                temperature      spo2  glucose_vital   albumin  globulin  ...  \
# heart_rate        0.242261 -0.110099       0.007117 -0.179344 -0.030702  ...
# sbp              -0.002332  0.045371      -0.001137  0.212399  0.239587  ...
# dbp              -0.029555  0.043339      -0.002737  0.144887 -0.033078  ...
# creatinine     0.008430   -0.152104   -0.172299  0.006796 -0.100660  0.074500
# sodium        -0.061873    0.114074    0.082359 -0.047884 -0.121542  0.027545
# potassium      0.025014    0.000055   -0.033574 -0.025004 -0.139390  0.062692
# magnesium     -0.017073   -0.035224   -0.042214 -0.011062 -0.036332  0.010939
# gcs            1.000000   -0.023259   -0.015868 -0.011857  0.011016 -0.020591
# hematocrit    -0.023259    1.000000    0.971881 -0.000746 -0.010619  0.005905
# hemoglobin    -0.015868    0.971881    1.000000  0.113513  0.218883 -0.011056
# mch           -0.011857   -0.000746    0.113513  1.000000  0.499994  0.825638
# mchc           0.011016   -0.010619    0.218883  0.499994  1.000000 -0.071383
# mcv           -0.020591    0.005905   -0.011056  0.825638 -0.071383  1.000000
# platelet       0.010511    0.173751    0.123861 -0.249798 -0.205826 -0.155036
# rbc           -0.010878    0.934878    0.912802 -0.289357  0.004657 -0.337164
# rdw            0.015418   -0.328105   -0.385871 -0.184243 -0.274659 -0.038702
# wbc           -0.014982    0.016552   -0.001540 -0.043409 -0.074087  0.000359
#
#                platelet       rbc       rdw       wbc
# heart_rate     0.036962 -0.029644  0.117097  0.091658
# sbp            0.066930  0.087168 -0.024040 -0.074924
# dbp            0.073244  0.274325 -0.091062 -0.012682
# mbp            0.073840  0.188787 -0.051365 -0.038310
# resp_rate      0.058180  0.043400  0.096782  0.082985
# temperature    0.052321  0.022093  0.020686 -0.010479
# spo2          -0.049940 -0.084898 -0.038112 -0.006768
# glucose_vital -0.008110 -0.004914  0.004612 -0.001986
# albumin        0.096963  0.424777 -0.277221 -0.128816
# globulin       0.141051  0.011257  0.058057  0.019639
# total_protein  0.110118  0.301199 -0.154118 -0.095985
# aniongap       0.050940  0.032826  0.170474  0.103009
# bicarbonate    0.090096  0.115089 -0.095129 -0.133104
# bun           -0.061863 -0.210772  0.289812  0.070108
# calcium        0.116866  0.237823 -0.054045 -0.061236
# chloride      -0.125403 -0.029326 -0.091750  0.004410
# creatinine    -0.056204 -0.165894  0.200290  0.036191
# sodium        -0.044965  0.094857 -0.041652 -0.022128
# potassium      0.043437 -0.020637  0.077574  0.079763
# magnesium     -0.034296 -0.033187  0.050119  0.054244
# gcs            0.010511 -0.010878  0.015418 -0.014982
# hematocrit     0.173751  0.934878 -0.328105  0.016552
# hemoglobin     0.123861  0.912802 -0.385871 -0.001540
# mch           -0.249798 -0.289357 -0.184243 -0.043409
# mchc          -0.205826  0.004657 -0.274659 -0.074087
# mcv           -0.155036 -0.337164 -0.038702  0.000359
# platelet       1.000000  0.217227 -0.054559  0.144231
# rbc            0.217227  1.000000 -0.276403  0.017755
# rdw           -0.054559 -0.276403  1.000000  0.062837
# wbc            0.144231  0.017755  0.062837  1.000000
#
# [30 rows x 30 columns]

# %%
# Correlation coefficients - summary

corrs_summary = summary_flat_mean.corr(method='pearson')
print(corrs_summary)
# Out:
# variable_name   albumin  aniongap  bicarbonate       bun   calcium  chloride  \
# variable_name
# albumin        1.000000  0.007187     0.187373 -0.168569  0.466171 -0.082041
# aniongap       0.007187  1.000000    -0.438445  0.427935  0.053167 -0.284957
# bicarbonate    0.187373 -0.438445     1.000000 -0.206143  0.254081 -0.287716
# spo2          -0.173230 -0.032049  -0.269450  0.030788  0.037686  1.000000
# temperature    0.049177 -0.073723   0.153347  0.051692  0.035901 -0.003479
# total_protein  0.193053 -0.158809  -0.069280  0.080532  0.012450 -0.050578
# wbc            0.005986  0.062558   0.122382 -0.110380 -0.018184 -0.022049
#
# variable_name  temperature  total_protein       wbc
# variable_name
# albumin          -0.002018       0.510402 -0.111600
# aniongap         -0.038326      -0.019325  0.105069
# bicarbonate       0.053108       0.125683 -0.125617
# bun              -0.138979      -0.091165  0.074135
# calcium          -0.080154       0.357028 -0.065009
# chloride         -0.002385      -0.100899  0.004263
# creatinine       -0.073046      -0.003724  0.030555
# dbp               0.053083       0.022742 -0.013877
# gcs              -0.003956      -0.051017 -0.020614
# globulin          0.007035       0.697457  0.011724
# glucose_vital    -0.003410      -0.007566 -0.006322
# heart_rate        0.232965      -0.161681  0.115282
# hematocrit        0.035136       0.187994 -0.000319
# hemoglobin        0.040880       0.185748 -0.014809
# magnesium        -0.144682       0.185160  0.070031
# mbp               0.038575       0.103042 -0.061506
# mch              -0.024420      -0.033166 -0.044873
# mchc              0.018649      -0.012781 -0.068910
# mcv              -0.040686      -0.035712 -0.006991
# platelet          0.030570       0.081424  0.151392
# potassium        -0.094602       0.042010  0.085736
# rbc               0.049177       0.193053  0.005986
# rdw              -0.073723      -0.158809  0.062558
# resp_rate         0.153347      -0.069280  0.122382
# sbp               0.051692       0.080532 -0.110380
# sodium            0.035901       0.012450 -0.018184
# spo2             -0.003479      -0.050578 -0.022049
# temperature       1.000000      -0.028577  0.029529
# total_protein    -0.028577       1.000000 -0.087529
# wbc               0.029529      -0.087529  1.000000
#
# [30 rows x 30 columns]

# %%
# Get proportion of pairs that are highly correlated


def high_corr(corrs_matrix, threshold):
    high_pairs = []
    variables = corrs_matrix.columns.tolist()
    for i in range(len(variables)):
        for j in range(i + 1, len(variables)):
            var1 = variables[i]
            var2 = variables[j]
            c = corrs_hourly.loc[var1, var2]
            if c > threshold:
                high_pairs.append((var1, var2, c))
    pairs_total = len(variables) * (len(variables) - 1) / 2
    pct_high = len(high_pairs) / pairs_total * 100
    print(pct_high)


high_corr(corrs_hourly, 0.8)
# Out:
# 1.1494252873563218

# %%
# skew - hourly

skew_hourly = hourly_ds[REPRESENTATIVE_VARS].skew()
print(skew_hourly)
# Out:
# heart_rate         0.528652
# sbp                0.666194
# dbp                1.088089
# resp_rate          0.866821
# spo2              -2.715422
# glucose_vital    105.576164
# gcs               -4.166523
# creatinine         5.104635
# potassium          1.498929
# wbc               12.953939
# dtype: float64

# %%
# skew - summary

skew_summary = summary_flat_mean[REPRESENTATIVE_VARS].skew()
print(skew_summary)
# Out:
# variable_name
# heart_rate        0.481263
# sbp               0.917619
# dbp               0.709997
# resp_rate         1.002898
# spo2             -1.689979
# glucose_vital    77.358146
# gcs              -3.712271
# creatinine        5.661512
# potassium         0.859153
# wbc              13.411606
# dtype: float64

# %%
# histograms for selected vars - hourly

hourly_ds[REPRESENTATIVE_VARS].hist()
pyplot.show()
# need to adjust the appearance

# %%
# histograms for selected vars - summary

summary_flat_mean[REPRESENTATIVE_VARS].hist()
pyplot.show()
# need to adjust the appearance
